# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhavPundir123/Data-Science-Workshop/blob/main/Project_2_Making_Static_And_Interactive_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# reading the csv file
pd.read_csv('population_total.csv')
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
# first look at the dataset
df_population_raw = pd.read_csv('population_total.csv')
df_population_raw.head()
# Out:
#   country    year    population
# 0   China  2020.0  1.439324e+09
# 1   China  2019.0  1.433784e+09
# 2   China  2018.0  1.427648e+09
# 3   China  2017.0  1.421022e+09
# 4   China  2016.0  1.414049e+09

# %% [markdown]
# # Making a pivot table

# %%
# dropping null values
df_population_raw.dropna(inplace=True)

# %%
# making a pivot table
df_pivot = df_population_raw.pivot(index='year', columns='country',values='population')

# %%
# selecting some countries
df_pivot = df_pivot[['United States','China','India']]

# %%
df_pivot.plot(kind='line', xlabel='Year', ylabel='Population', title='Population (1955-2020)',figsize=(10,5))
# Out:
# <Axes: title={'center': 'Population (1955-2020)'}, xlabel='Year', ylabel='Population'>

# %%
# selecting only one year
df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]

# %%
# showing new dataframe
df_pivot_2020
# Out:
# country  United States         China         India
# year
# 2020.0     331002651.0  1.439324e+09  1.380004e+09

# %%
# transpose dataframe from rows to columns or viceversa
df_pivot_2020.T
# Out:
# year                 2020.0
# country
# United States  3.310027e+08
# China          1.439324e+09
# India          1.380004e+09

# %%
# making barplot
df_pivot_2020.T.plot(kind='bar', color='orange', xlabel='Country', ylabel='Population', title='Population (2020)',figsize=(8,5))
# Out:
# <Axes: title={'center': 'Population (2020)'}, xlabel='Country', ylabel='Population'>

# %% [markdown]
# # Barplot grouped by N variables

# %%
df_pivot
# Out:
# country  United States         China         India
# year
# 1955.0     171685336.0  6.122416e+08  4.098806e+08
# 1960.0     186720571.0  6.604081e+08  4.505477e+08
# 1965.0     199733676.0  7.242190e+08  4.991233e+08
# 1970.0     209513341.0  8.276014e+08  5.551898e+08
# 1975.0     219081251.0  9.262409e+08  6.231029e+08
# 1980.0     229476354.0  1.000089e+09  6.989528e+08
# 1985.0     240499825.0  1.075589e+09  7.843600e+08
# 1990.0     252120309.0  1.176884e+09  8.732778e+08
# 1995.0     265163745.0  1.240921e+09  9.639226e+08
# 2000.0     281710909.0  1.290551e+09  1.056576e+09
# 2005.0     294993511.0  1.330776e+09  1.147610e+09
# 2010.0     309011475.0  1.368811e+09  1.234281e+09
# 2015.0     320878310.0  1.406848e+09  1.310152e+09
# 2016.0     323015995.0  1.414049e+09  1.324517e+09
# 2017.0     325084756.0  1.421022e+09  1.338677e+09
# 2018.0     327096265.0  1.427648e+09  1.352642e+09
# 2019.0     329064917.0  1.433784e+09  1.366418e+09
# ...

# %%
# selecting few years
df_pivot_sample = df_pivot[df_pivot.index.isin([1980,1990,2000,2010,2020])]

# %%
# making grouped barplot
df_pivot_sample.plot(kind='bar',xlabel= 'Year', ylabel='Population', title='Population (1980-2020)',figsize=(10,5))
# Out:
# <Axes: title={'center': 'Population (1980-2020)'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# # Pie chart

# %%
# changing column name
df_pivot_2020.columns
# Out:
# Index(['United States', 'China', 'India'], dtype='object', name='country')

# %%
# The rename operation is not needed as the column '2020' does not exist in df_pivot_2020
# df_pivot_2020.rename(columns={2020:'2020'} , inplace=True)

# %%
# making the plot
df_pivot_2020.T.plot(kind='pie', y=2020.0, figsize=(8, 5), title='Population Distribution (2020)', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Population Distribution (2020)'}, ylabel='2020.0'>

# %% [markdown]
# # Boxplot

# %%
df_pivot['United States'].plot(kind='box', color = 'Green', figsize=(8,5), title='Population Distribution (United States)')
# Out:
# <Axes: title={'center': 'Population Distribution (United States)'}>

# %%
# Multiple boxplots
df_pivot.plot(kind='box', color = 'Green', figsize=(8,5), title='Population Distribution')
# Out:
# <Axes: title={'center': 'Population Distribution'}>

# %%
import pandas as pd
import cufflinks as cf
from IPython.display import display, HTML
cf.set_config_file(sharing='public', theme = 'white' , offline= True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# reading the csv file
df_population_raw= pd.read_csv('population_total.csv')

# %% [markdown]
# # Lineplot

# %%
# selecting a few years
df_pivot_sample = df_pivot[df_pivot.index.isin([1980, 1990, 2000, 2010, 2020])]
