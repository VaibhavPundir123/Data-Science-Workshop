# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhavPundir123/Data-Science-Workshop/blob/main/Data_Analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
+skill==
"python"
# Out:
#   File "/tmp/ipython-input-3-86436275.py", line 1
#     +skill==
#             ^
# SyntaxError: invalid syntax

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
str._add_("Data","Analyst")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1-2206202192.py in <cell line: 0>()
# ----> 1 str._add_("Data","Analyst")
#
# AttributeError: type object 'str' has no attribute '_add_'

# %%
result = "Data" + "Analyst"
print(result)  # Output: DataAnalyst

# %%
"Data" + " Analyst "

# %%
"Data" + " Analyst"*10

# %%
len("Data Analyst")

# %%
role="Data Analyst"
skill="Python"

# %%
'Role:'+ role

# %%
"Role:{}.format(role)"

# %%
job_skills={'tableau', 'python', 'sql'}

# %%
help(set)

# %%
job_skills

# %%
job_skills.add('looker')

# %%
job_skills.add('sql')

# %%
job_skills

# %%
# tuples
lukes_skill=('python', 'tableau', 'sql')
lukes_skill

# %%
help(tuple)

# %%
new_skills=('excel' , 'looker')

# %%
lukes_skill + new_skills

# %%
range(10)

# %%
tuple(range(10))

# %%
# operators
# AND x and y
# OR x or y
# NOT x not y

# %%
job_work_from_home=True
job_health_insurance=False
job_no_degree_mentioned=True
job_work_from_home or job_health_insurance

# %%
# Membership Operators
# in
# not in

# %%
"Data" in "Data Analyst"

# %%
job_skills=['tableau', 'python', 'sql']
'python'not in job_skills

# %%
# Identity Operator
# is
# is not
# they are used to compare the memory locations of two variables

# %%
salary_kelly=100000
salary_luke = 50000
salary_kelly is salary_luke

# %%
id(salary_kelly)

# %%
id(salary_luke)

# %%
# Bitwise operators
# & AND
# | OR
# ~ NOT
# ^ XOR
# << LEFT SHIFT
# >> RIGHT SHIFT
# they compare the binary representation of two numbers

# %%
bin(10)

# %%
# for loops
# while loop
# loops are used to execute a block of code repeatedly

# %%
numbers=[1,2,3,4,5]
for number in numbers:
    print(number)

# %%
years_experience=[1,2,3,4,5]
for year in years_experience:
    print(year)

# %%
years_experience={'Luke':3, 'James':4, 'Michael':5}

# %%
for key,values in years_experience.items():
  if values>3:
    print(key,'has',values, 'years of experience')

# %%
# List Comprehension
# set comprehension
# tuple comprehension
# dictionary comprehension
# it is a concise way to create lists

# %%
numbers=[]
for number in range(10):
  numbers.append(number)
print(numbers)

# %%
# syntax
numbers= [x for x in range(10)]
numbers

# %%
my_skills = ['Python', 'Excel', 'SQL']
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]
qualified_roles=[]
for job in job_roles:
  qualified = True
  for skills in my_skills:
   if skills not in job['skills']:
    qualified = False
   if qualified:
    qualified_roles.append(job['role'])
print(qualified_roles)

# %%
# Funtion
# they are used to perform a specific task or set of tasks
# Types of funtions
# 1. Built-in functions---------print()
# 2. User-defined functions-----def my_function
# 3. Lambda Funtion-------------lambda x:x+1
# 4. Standart Library Function---math.sqrt()
# 5. Third party Library Function-numpy.array()

# %%
data_salaries = [95000,100000,850000,970000,1400000]

# %%
min(data_salaries)

# %%
max(data_salaries)

# %%
sum(data_salaries)

# %%
sorted(data_salaries)

# %%
# user defined functions
# they are used to perform a specific task or set of tasks

# %%
base_salary=100000
bonus_rate=0.1

def calculate_salary(base_salary,bonus_rate):

  total_salary=base_salary*(1+bonus_rate)
  return total_salary

# %%
calculate_salary(base_salary,bonus_rate)

# %%
# lamda functions
# they are used to create small anonymous functions
# anonymous funtions are functions that do not have a name
# they are statred with the lambda keyword

# %%
mul_two = lambda x:x*2

# %%
mul_two(12)

# %%
(lambda x,y:x*2+y)(3,4)

# %%
# Data filtering Example
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

# %%
list(filter(lambda job: job['remote'] and 'Python' in job['job_skills'],jobs_data))

# %%
# modules

# %%
import my_module

# %%
my_module.skill_list

# %%
my_module.skill('Python')

# %%
salary_list=[9800,10000,85000,97000,140000]

# %%
from statistics import mean, median, mode
statistics.mean(salary_list)

# %%
mode(salary_list)

# %%
median(salary_list)

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %%
from datetime import datetime

# %%
datetime.now()

# %%
test_date=data_science_jobs[0]['job_date']

# %%
print(datetime.strptime(test_date,'%Y-%m-%d') )

# %%
# for cleaning the whole data
for job in data_science_jobs:
  print(datetime.strptime(job['job_date'],'%Y-%m-%d'))

# %%
import ast
for job in data_science_jobs:
  job['job_skills']=ast.literal_eval(job['job_skills'])

# %%
data_science_jobs

# %%
# opening a file in toolbar
file = open('sample_data/california_housing_test.csv')
content= file.read()
file.close()

# %%
import pandas as pd
contents = pd.read_csv('sample_data/california_housing_test.csv')
contents

# %%
# !pip install pandas

# %%
# !pip list

# %%
import random

salary_list=[random.randint(50000,100000) for _ in range(100_000)]

# %%
# %%timeit

import statistics
statistics.mean(salary_list)

# %%
# importing numpy panda
import numpy as np

# %%
# %%timeit
np.mean(salary_list)

# %%
my_array=np.array(salary_list)

# %%
my_array.mean()

# %%
import pandas as pd

# %%
df=pd.read_csv('sample_data/california_housing_test.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df['total_bedrooms']

# %%
# to access the data we can either put . or put in ''

# %%
df.total_bedrooms[0]

# %%
# from here we start downloading the datasets on which analysis needs to be done
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ...

# %%
# from here we start writing the command for importing the dataset
from datasets import load_dataset

# %%
# here we load the dataset and include the path of the dataset, it could be on the web or in a folder
dataset=load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
# here the dataset is transfered to pandas before that we conveted it into a variable
df=dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.tail(20)
# Out:
#               job_title_short  \
# 785721       Business Analyst
# 785722       Business Analyst
# 785723          Data Engineer
# 785724          Data Engineer
# 785725         Data Scientist
# 785726          Data Engineer
# 785727          Data Engineer
# 785728  Senior Data Scientist
# 785729          Data Engineer
# 785730          Data Engineer
# 785731          Data Engineer
# 785732          Data Engineer
# 785733      Software Engineer
# 785734       Business Analyst
# 785735   Senior Data Engineer
# 785736      Software Engineer
# 785737           Data Analyst
# 785738       Business Analyst
# 785739          Data Engineer
# 785740      Software Engineer
#
#                                                 job_title  \
# 785721                           IT Business Analyst Data
# 785722         Business Analytics Training and Internship
# 785723                                      Data Engineer
# 785724                 Junior Consultant Data Engineering
# ...

# %%
df['job_title_short'].head()
# Out:
# 0    Senior Data Engineer
# 1            Data Analyst
# 2           Data Engineer
# 3           Data Engineer
# 4           Data Engineer
# Name: job_title_short, dtype: object

# %%
df.iloc[90:100,0:1]

# %%
df.info()

# %%
df.head(10)

# %%
df.tail(20)

# %%
df[['job_title_short','job_location']].iloc[90:100,0:2]

# %%
df.iloc[90:100,0:2]

# %%
# df.info()----get key info on the dataset
# df.described()----get key numerical statistics
# df['column_name'].unique---number of distinct values
# df.shape---get the rows and columns
# len(df)--get number of rows
# df.head()---get first 5 rows
# df.tail()---get last 5 rows
# df.count()---number of non na values

# %%
df.info()

# %%
df.count()

# %%
len(df)

# %%
df.head()

# %%
df.tail()

# %%
df.columns

# %%
df.describe()

# %%
# it gives unique value
df.job_title_short.unique()

# %%
# It gives boolean value ---True and False
df.job_title_short == 'Data Scientist'

# %%
df.job_title_short == 'Data Analyst'

# %%
# First df: Specifies the DataFrame from which you want to extract data.
# Second df[df.job_title_short == 'Data Analyst']: Specifies how you want to extract the data from the first df.

df[df.job_title_short == 'Data Analyst']

# %%
# Start from 4:45:01 Time stamp on youtube

# %%
df[(df.job_title_short == 'Data Analyst') & (df.job_location == 'San Francisco')]

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna()) ]

# %%
df.info()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.describe()

# %%
df['job_title_short'].unique()

# %%
df.sort_values('job_posted_date')

# %%
# dropping a column name from the data
df.drop(labels='salary_hour_avg', axis=1)

# %%
# The code df.drop(labels='salary_hour_avg', axis=1) is a command used in the pandas library to remove a column named 'salary_hour_avg' from a DataFrame named df. Here’s a breakdown of the components:

# df: The DataFrame from which you want to drop a column.
# drop(): A pandas method used to drop specified labels from rows or columns.
# labels='salary_hour_avg': Specifies the label (or name) of the column to be dropped.
# axis=1: Indicates that the operation is to be performed on columns (axis=0 would be for rows).
# So, this code effectively removes the column named 'salary_hour_avg' from the DataFrame df.

# %%
# With inplace=True:inplace=True: Modifies the original DataFrame df directly, and no new DataFrame is returned.Without inplace=True, the drop method would return a new DataFrame with the specified column removed, and you would need to assign it back to df or another variable to keep the changes.

# %%
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df.dropna(subset=['salary_year_avg'])

# %%
# The code df.dropna(subset=['salary_year_avg']) is a command used in the pandas library to remove rows from a DataFrame df where the column 'salary_year_avg' has missing (NaN) values. Here’s a breakdown of the components:

# df: The DataFrame from which you want to drop rows.
# dropna(): A pandas method used to remove missing values.
# subset=['salary_year_avg']: Specifies that the operation should only consider the column 'salary_year_avg'.
# So, this code will remove all rows in the DataFrame df that have NaN values in the 'salary_year_avg' column.

# %%
df.info()

# %%
#  Pandas :Analyzing--------Statistics-------
# df.count()
# df.sum()
# df.min()
# df.max()
# df.mean()
# df.median()
# df.mode()
# df.std()
# df.var()
# df.quantile()
# df.idxmax()
# df.column_name.value_counts()
# df.cumsum()--cumulative sum of values
# df.min()/df.max()---minimum/maximum values
# df.idxmin()/df.idxmax()----indexes of min/max value

# %%
# to find out any value it needs to be in sqaure bracket appended with a dot and the value that needs to be calculated
df['salary_year_avg'].median()

# %%
df['salary_year_avg'].min()

# %%
df['salary_year_avg'].idxmin()

# %%
min_salary=df['salary_year_avg'].idxmin()

# %%
# The code df.iloc[min_salary] is used to access a specific row in a pandas DataFrame df by its integer position index, specified by the variable min_salary.

# Here's a detailed breakdown:

# df: The pandas DataFrame from which you want to access a row.
# iloc: A pandas method used for integer-location based indexing for selection by position (from 0 to length-1 of the axis).
# min_salary: An integer variable representing the position index of the row you want to access.

df.iloc[min_salary]

# %%
df['job_title_short'].value_counts()

# %%
# start from 5:03:25 youtube

# %%
#  syntax for groupby
# df.groupby("column to group")["column to aggregate"].your_agg_method()

# %%
df.groupby('job_title_short')['salary_year_avg'].min()

# %%
df.groupby('job_title_short')['salary_year_avg'].median()

# %%
df.groupby(['job_title_short','job_country'])['salary_year_avg'].median()

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min','max','mean','median'])

# %%
# Install Datasets Library
# !pip install datasets

# Import Libraries
# ---------import pandas as pd----------
# ---------from datasets import load_dataset-------
# ---------import matplotlib.pyplot as plt---------

# Loading Datasets
# --------datasets= load_dataset('lukebarousse/data_jobs')--------
# --------df=datasets['train'].to_pandas()------------------------

# Data Cleanup
# --------df.drop(labels='salary_hour_avg', axis=1, inplace=True)----

# %%
df['job_country']

# %%
df['job_country'].value_counts()

# %%
df['job_country'].value_counts().head(20)
# Putting it all together, the code df['job_country'].value_counts().head(20) does the following:

# Accesses the job_country column in the DataFrame df.
# Counts the occurrences of each unique value in that column.
# Sorts the counts in descending order.
# Retrieves the top 20 most frequent values along with their counts.

# %%
df['job_country'].isin(['United States','India'])


# The code snippet df['job_country'].isin(['United States', 'India']) is used to check whether each element in the job_country column of the DataFrame df is present in the list ['United States', 'India']. Here's a detailed breakdown of each part of this code:

# df: This is a DataFrame object from the Pandas library.

# ['job_country']: This selects the column named job_country from the DataFrame df.

# .isin(['United States', 'India']): This is a method provided by Pandas that checks if each element in the job_country column is contained in the list ['United States', 'India'].

# %%
df['job_country'].isin(['United States','India']).any()

# %%
filtered_df = df[df['job_country'].isin(['United States'])]

# %%
filtered_df

# %%
us_jobs = df[df['job_country'] == 'United States']

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min','max','mean','median']).sort_values(by='median',ascending=False)

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.5
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.7.0
# anyio                            3.7.1
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.1.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.15.0
# backcall                         0.2.0
# ...

# %%
# importing matplotlib library so that plt could be defined

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# import numpy as np: This imports the NumPy library, which is used for numerical operations in Python, and gives it the alias np.

# import matplotlib.pyplot as plt: This imports the Matplotlib library, specifically the pyplot module, which is used for creating plots and graphs, and gives it the alias plt.

# x = np.arange(0, 5, 0.1): This creates an array x with values starting from 0 to just below 5, with a step of 0.1. The np.arange function generates this range of values.

# y = np.sin(x): This creates an array y where each element is the sine of the corresponding element in the x array. The np.sin function computes the sine of each value.

# plt.plot(x, y): This plots the values of x on the x-axis and the corresponding values of y (which are the sine of x) on the y-axis.

# plt.show(): This displays the plot in a window.

# %%
x=[1,2,3,4]
y=[1,2,3,4]
plt.plot(x,y)
plt.show()

# %%
# Plotting Job Posting Date
df.job_posted_date.head()

# %%
us_jobs

# %%
plt.plot(us_jobs['job_country'],us_jobs['salary_year_avg'])
plt.show()

# %%
date_counts = df['job_posted_date'].value_counts()
date_counts = date_counts.sort_index()

# %%
date_counts
# Out:
# job_posted_date
# 2023-01-01 00:00:04    1
# 2023-01-01 00:00:07    1
# 2023-01-01 00:00:22    1
# 2023-01-01 00:00:24    1
# 2023-01-01 00:00:27    1
#                       ..
# 2023-12-31 23:40:18    2
# 2023-12-31 23:40:22    2
# 2023-12-31 23:40:31    2
# 2023-12-31 23:40:32    1
# 2023-12-31 23:59:58    2
# Name: count, Length: 607192, dtype: int64

# %%
# Bar chart -Counts of Job Posting
df.job_title_short
# Out:
# 0         Senior Data Engineer
# 1                 Data Analyst
# 2                Data Engineer
# 3                Data Engineer
# 4                Data Engineer
#                   ...
# 785736       Software Engineer
# 785737            Data Analyst
# 785738        Business Analyst
# 785739           Data Engineer
# 785740       Software Engineer
# Name: job_title_short, Length: 785741, dtype: object

# %%
job_counts = df['job_title_short'].value_counts()

# %%
plt.bar(job_counts.index, job_counts.values)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts = df['job_title_short'].value_counts().head(10)

# %%
# plotting of graph in vertical manner
plt.bar(job_counts.index, job_counts.values)
# Out:
# <BarContainer object of 10 artists>

# %%
# plotting of a graph in horizontal manner using (barh)
# plotting of a graph in normal manner using (bar)
# plotting of graph in ascending order or descending order
# For naming the header of the graph we use Title
job_counts = job_counts.sort_values(ascending=True)
plt.barh(job_counts.index, job_counts.values)
plt.title('Postings by Job Title')
plt.show()

# %%
# Matplotlib Labeling
# xticks  rotatation is basically tilting the name at the x axis in 45 degree
# ha stands for horizontal alignment
plt.bar(job_counts.index, job_counts.values)
plt.title('Postings by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# Index Management
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.sample(10)
# Out:
#             job_title_short  \
# 40376        Data Scientist
# 310696     Business Analyst
# 42238        Data Scientist
# 120173         Data Analyst
# 643523        Data Engineer
# 523916       Data Scientist
# 766000        Data Engineer
# 639160  Senior Data Analyst
# 220624     Business Analyst
# 95634          Data Analyst
#
#                                                 job_title  \
# 40376   Intelligence/Data Specialist 1 - Northern Virg...
# 310696                                  Financial Analyst
# 42238                       Data Science Analyst/Engineer
# 120173              Consultant(e) Data Analyst / Power BI
# 643523                                      Data engineer
# 523916                          Apprenti·e data scientist
# 766000            EL6 - Senior Associate Data Engineer L2
# 639160                 Senior Data Analyst / Data Analyst
# 220624                                  Financial Analyst
# 95634                                  Data(Risk) Analyst
#
# ...

# %%
df.index.name

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
# Three methods
# df.reset_index()
# df.set_index()
# df.sort_index()

# %%
df_usa = df[df['job_country'] == 'United States']

# %%
df_usa
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_usa.reset_index(inplace=True)

# %%
df_usa
# Out:
#          index       job_title_short  \
# 0            0  Senior Data Engineer
# 1            3         Data Engineer
# 2            5         Data Engineer
# 3            6  Senior Data Engineer
# 4            9        Data Scientist
# ...        ...                   ...
# 206287  785673        Data Scientist
# 206288  785685          Data Analyst
# 206289  785692        Data Scientist
# 206290  785703          Data Analyst
# 206291  785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df_usa.set_index('index',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a2e36561eb8a> in <cell line: 1>()
# ----> 1 df_usa.set_index('index',inplace=True)
#
# NameError: name 'df_usa' is not defined

# %%
df_usa
# Out:
#              job_title_short  \
# index
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# index
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
median_pivot = df_usa.pivot_table(values='salary_year_avg',index='job_title_short', aggfunc=['median','min','max'])

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_values(by=('median','salary_year_avg'),ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0         55000.0        475000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Software Engineer                130000.0         48982.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Business Analyst                  90000.0         35000.0        387460.0
# Data Analyst                      90000.0         25000.0        375000.0

# %%
# sorted coloumn by the alphabet
median_pivot.sort_index(inplace=True)

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
# !pip install pandas
import pandas as pd

# %%
# Out:
# <ipython-input-43-35e0632d8f83>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['job_posted_date'] = pd.to_datetime(df_usa['job_posted_date'])

# %%
# Convert 'job_posted_date' to datetime if it's not already
df_usa['job_posted_date'] = pd.to_datetime(df_usa['job_posted_date'])
# Out:
# <ipython-input-44-5bf56e89e116>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['job_posted_date'] = pd.to_datetime(df_usa['job_posted_date'])

# %%
# Now you can extract the month name
df['job_posted_month'] = df_usa['job_posted_date'].dt.strftime('%B')

# %%
df_usa
# Out:
#              job_title_short  \
# index
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# index
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
# Merging  two dataframes
job_data = {
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Software Engineer', 'Product Manager', 'Marketing Director', 'HR Manager'],
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'job_location': ['Mountain View, CA', 'Redmond, WA', 'Cupertino, CA', 'Beaverton, OR', 'Seattle, WA']
}

# %%
company_data = {
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'industry': ['Technology', 'Technology', 'Technology', 'Apparel', 'Food & Beverage'],
    'company_size': ['100,000+', '100,000+', '100,000+', '75,000+', '346,000+']
}

# %%
df_jobs = pd.DataFrame(job_data)
df_companies = pd.DataFrame(company_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0b1229190655> in <cell line: 1>()
# ----> 1 df_jobs = pd.DataFrame(job_data)
#       2 df_companies = pd.DataFrame(company_data)
#
# NameError: name 'job_data' is not defined

# %%
df_jobs
# Out:
#    job_id           job_title company_name       job_location
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA

# %%
df_companies
# Out:
#   company_name         industry company_size
# 0       Google       Technology     100,000+
# 1    Microsoft       Technology     100,000+
# 2        Apple       Technology     100,000+
# 3         Nike          Apparel      75,000+
# 4    Starbucks  Food & Beverage     346,000+

# %%
# Merge the two datasets on the 'job_id' column
df_job_company = df_jobs.merge(df_companies, on='company_name')

# %%
df_job_company
# Out:
#    job_id           job_title company_name       job_location  \
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA
#
#           industry company_size
# 0       Technology     100,000+
# 1       Technology     100,000+
# 2       Technology     100,000+
# 3          Apparel      75,000+
# 4  Food & Beverage     346,000+

# %%
df_US = df[df['job_country'] == 'United States'].copy()
# df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')
df_US_pivot = df_US.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')
df_US_pivot = df_US_pivot.reset_index()
df_US_pivot['job_posted_month_no'] = pd.to_datetime(df_US_pivot['job_posted_month'], format='%B').dt.month
df_US_pivot = df_US_pivot.sort_values('job_posted_month_no')
df_US_pivot = df_US_pivot.set_index('job_posted_month')
df_US_pivot = df_US_pivot.drop(columns='job_posted_month_no')

df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
job_postings_jan = pd.DataFrame({
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company A', 'Company B', 'Company C', 'Company D', 'Company E'],
    'job_posted_date': pd.to_datetime(['2024-01-02', '2024-01-07', '2024-01-14', '2024-01-19', '2024-01-24'])
})

# %%
job_postings_jan
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24

# %%
# Sample dataset of job postings in February
job_postings_feb = pd.DataFrame({
    'job_id': [6, 7, 8, 9, 10],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company F', 'Company G', 'Company H', 'Company I', 'Company J'],
    'job_posted_date': pd.to_datetime(['2024-02-05', '2024-02-09', '2024-02-12', '2024-02-18', '2024-02-22'])
})

# %%
job_postings_feb
# Out:
#    job_id                  job_title    company job_posted_date
# 0       6             Data Scientist  Company F      2024-02-05
# 1       7               Data Analyst  Company G      2024-02-09
# 2       8  Machine Learning Engineer  Company H      2024-02-12
# 3       9             Data Scientist  Company I      2024-02-18
# 4      10              Data Engineer  Company J      2024-02-22

# %%
# Concatenate the two DataFrames
job_postings_combined = pd.concat([job_postings_jan, job_postings_feb], ignore_index=True)

# %%
job_postings_combined
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24
# 5       6             Data Scientist  Company F      2024-02-05
# 6       7               Data Analyst  Company G      2024-02-09
# 7       8  Machine Learning Engineer  Company H      2024-02-12
# 8       9             Data Scientist  Company I      2024-02-18
# 9      10              Data Engineer  Company J      2024-02-22

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# Convert 'job_posted_date' to datetime if it's not already
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# Now extract the month
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-baee216d1f52> in <cell line: 1>()
# ----> 1 df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
# Convert 'job_posted_date' to datetime if it's not already
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce') # Handle potential errors during conversion

# Now extract the month
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-962c432f19d2> in <cell line: 2>()
#       1 # Convert 'job_posted_date' to datetime if it's not already
# ----> 2 df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce') # Handle potential errors during conversion
#       3
#       4 # Now extract the month
#       5 df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-75d056261fec> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from datasets import load_dataset
#       3 import matplotlib.pyplot as plt
#       4
#       5 # Loading Data
#
# ModuleNotFoundError: No module named 'datasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Convert 'job_posted_date' to datetime if it's not already
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce') # Handle potential errors during conversion

# Now extract the month
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# make data frame for each month using a loop
months = df['job_posted_month'].unique()

# write this with dict comprehension
dict_months = {month: df[df['job_posted_month'] == month] for month in months}

# long way
# dict_months = {}
# for month in months:
#     dict_months[month] = df[df['job_posted_month'] == month]

type(dict_months)
# Out:
# dict

# %%
dict_months['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
quarter_1 = [dict_months['Jan'], dict_months['Feb'], dict_months['Mar']]

df_q1 = pd.concat(quarter_1, ignore_index=True)

df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
# Pandas Exporting Data Frames

# %%
# exporting and the saving the file in the folder
df_q1.to_csv('quarter_1.csv')

# %%
# reading the file on jupyter or google collab
pd.read_csv('quarter_1.csv',index_col=0)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
# exporting the data in excel format
df_q1.to_excel('quarter_1.xlsx')

# %%
# exporting very large dataset
df.to_parquet('df.parquet')

# %%
# to_pickle()
df.to_pickle('df.pkl')

# %%
# Doing analysis on particular coloumn using apply function, which is a method or parameter of dataframe
# here we have created a function using def and returning salary
def inflation(salary):
    return salary * 1.03

df['salary_year_inflated'] = df['salary_year_avg'].apply(inflation)

df[pd.notna(df['salary_year_avg'])][['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df['salary_year_inflated'] = df['salary_year_avg'].apply(lambda salary: salary * 1.03)

df[pd.notna(df['salary_year_avg'])][['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df['job_skills']
# Out:
# 0                                                      None
# 1         ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2         ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3         ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4         ['bash', 'python', 'oracle', 'aws', 'ansible',...
#                                 ...
# 785736    ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                       ['sas', 'sas', 'sql', 'excel']
# 785738                              ['powerpoint', 'excel']
# 785739    ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                      ['aws', 'flow']
# Name: job_skills, Length: 785741, dtype: object

# %%
df['job_skills'][0]

# %%
type(df['job_skills'][0])
# Out:
# NoneType

# %%
import ast

# Check if the value is None before attempting to evaluate it
if df['job_skills'][0] is not None:
    result = ast.literal_eval(df['job_skills'][0])
    print(result)
else:
    print("The value at df['job_skills'][0] is None.")
# Out:
# The value at df['job_skills'][0] is None.

# %%
import ast

# Check if the value is None before attempting to evaluate it
if df['job_skills'][0] is not None:
    result = ast.literal_eval(df['job_skills'][0])
    print(result)
    print(type(result)) # Print the type of the result
else:
    print("The value at df['job_skills'][0] is None.")
# Out:
# The value at df['job_skills'][0] is None.

# %%
df['job_skills']
# Out:
# 0                                                      None
# 1         ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2         ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3         ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4         ['bash', 'python', 'oracle', 'aws', 'ansible',...
#                                 ...
# 785736    ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                       ['sas', 'sas', 'sql', 'excel']
# 785738                              ['powerpoint', 'excel']
# 785739    ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                      ['aws', 'flow']
# Name: job_skills, Length: 785741, dtype: object

# %%
# explode method
data = {
    'job_title_short': ['Data Analyst', 'Data Scientist', 'Data Engineer'],
    'job_skills': [['excel', 'sql', 'python'], ['python', 'r'], ['aws', 'python', 'airflow']]
}

df_skills = pd.DataFrame(data)

df_skills
# Out:
#   job_title_short              job_skills
# 0    Data Analyst    [excel, sql, python]
# 1  Data Scientist             [python, r]
# 2   Data Engineer  [aws, python, airflow]

# %%
# n Python, the explode method is commonly used in the context of pandas, a popular data manipulation library. The explode method is applied to a pandas DataFrame or Series to transform each element of a list-like column to a separate row, replicating the index values.

# %%
df_exploded = df_skills.explode('job_skills')

df_exploded
# Out:
#   job_title_short job_skills
# 0    Data Analyst      excel
# 0    Data Analyst        sql
# 0    Data Analyst     python
# 1  Data Scientist     python
# 1  Data Scientist          r
# 2   Data Engineer        aws
# 2   Data Engineer     python
# 2   Data Engineer    airflow

# %%
df_exploded.value_counts('job_skills')
# Out:
# job_skills
# python     3
# airflow    1
# aws        1
# excel      1
# r          1
# sql        1
# Name: count, dtype: int64

# %%
df_exploded.value_counts('job_skills').plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
# Convert string representation to actual list, checking for NaN values first
import ast
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

df[['job_title_short', 'job_skills']].head(5)
# Out:
#         job_title_short                                         job_skills
# 0  Senior Data Engineer                                               None
# 1          Data Analyst         [r, python, sql, nosql, power bi, tableau]
# 2         Data Engineer  [python, sql, c#, azure, airflow, dax, docker,...
# 3         Data Engineer  [python, c++, java, matlab, aws, tensorflow, k...
# 4         Data Engineer  [bash, python, oracle, aws, ansible, puppet, j...

# %%
# Explode 'job_skills' so each skill gets its own row
df_exploded = df.explode('job_skills')

# %%
df_exploded['job_skills']
# Out:
# 0               None
# 1                  r
# 1             python
# 1                sql
# 1              nosql
#              ...
# 785739         kafka
# 785739    kubernetes
# 785739        docker
# 785740           aws
# 785740          flow
# Name: job_skills, Length: 3777320, dtype: object

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9b6067aed4be> in <cell line: 2>()
#       1 df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# Explode job_skills column
df_skills = df_skills.explode('job_skills')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e31e817b3b0c> in <cell line: 2>()
#       1 # Explode job_skills column
# ----> 2 df_skills = df_skills.explode('job_skills')
#
# NameError: name 'df_skills' is not defined

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
# Extract the month from the job_posted_date.
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# %%
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month
df_DA_explode = df_DA.explode('job_skills')

# %%
# Let's pivot the data to get the count (or size) of each skill for each month.
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills',  aggfunc='size', fill_value=0)

df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
# We need to sort the skills to be in order of count to make it easier to plot the top X.

# %%
# Create a total row
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
# Order columns by total count
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
# Drop total row
df_DA_pivot = df_DA_pivot.drop('Total')

df_DA_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
# code snippet from `6_Exercise_Job_Demand.ipynb`
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_pivot = df_DA_pivot.set_index('job_posted_month')
df_DA_pivot = df_DA_pivot.drop(columns='job_posted_month_no')

df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# Jan               11336   8170    6606     5596      4285  3607  3830
# Feb                7947   5772    4751     3936      3307  2576  2634
# Mar                7868   5675    4741     4051      3176  2650  2554
# Apr                7553   5496    4557     3776      3106  2399  2598
# May                6617   4773    4070     3245      2695  2093  1940
# Jun                7584   5724    4707     3812      3275  2442  2174
# Jul                7687   5513    4831     3928      3350  2444  2118
# Aug                8823   6482    5576     4533      3859  2975  2560
# Sep                6829   4886    4229     3446      3118  2146  1880
# Oct                7474   5217    4693     3709      3340  2380  2114
# Nov                6652   4776    4233     3284      3012  2159  1738
# Dec                6058   4376    4196     3139      2857  2125  1858
#
# ...

# %%
df_DA_pivot.iloc[:, :5].plot(kind='line')

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
# create a simple subplot
fig, ax = plt.subplots()

# plot the data
df['job_title_short'].value_counts().plot(kind='bar', ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(1, 2)

df['job_title_short'].value_counts().plot(kind='bar', ax=ax[0])
df['job_schedule_type'].value_counts().head(3).plot(kind='bar', ax=ax[1])

# fix the overlap
fig.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(1, 2)

ax[0].bar(df['job_title_short'].value_counts().index, df['job_title_short'].value_counts())
ax[1].bar(df['job_schedule_type'].value_counts().head(3).index, df['job_schedule_type'].value_counts().head(3))

fig.tight_layout()

plt.show()

# %%
df_skills = df.copy()
df_skills = df_skills.explode('job_skills')
skills_count = df_skills.groupby(['job_skills', 'job_title_short']).size()
df_skills_count = skills_count.reset_index(name='skill_count')
df_skills_count.sort_values(by='skill_count', ascending=False, inplace=True)

df_skills_count
# Out:
#       job_skills            job_title_short  skill_count
# 1480      python             Data Scientist       113711
# 1822         sql              Data Engineer       113130
# 1479      python              Data Engineer       108022
# 1821         sql               Data Analyst        92428
# 1823         sql             Data Scientist        78982
# ...          ...                        ...          ...
# 2173       webex      Senior Data Scientist            1
# 1054  mattermost             Data Scientist            1
# 270      clickup  Machine Learning Engineer            1
# 797       heroku        Senior Data Analyst            1
# 1128    msaccess               Data Analyst            1
#
# [2256 rows x 3 columns]

# %%
job_titles = df_skills_count['job_title_short'].unique().tolist()

job_titles = job_titles[:3]

job_titles
# Out:
# ['Data Scientist', 'Data Engineer', 'Data Analyst']

# %%
fig, ax = plt.subplots(len(job_titles), 1)

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_count[df_skills_count['job_title_short'] == job_title].head(5)
    df_plot.plot(kind='barh', x='job_skills', y='skill_count', ax=ax[i], title=job_title)
    ax[i].invert_yaxis()
    ax[i].set_ylabel('')
    ax[i].legend().set_visible(False)

fig.suptitle('Counts of Top Skills in Job Postings', fontsize=15)
plt.show()

# %%
# tight_layout(): automatically adjusts the spacing between subplots and the figure margins to prevent overlapping of axes labels, titles, and tick labels.

# %%
fig, ax = plt.subplots(len(job_titles), 1)
for i, job_title in enumerate(job_titles):
    df_skills_count[df_skills_count['job_title_short'] == job_title].head(5).plot(kind='barh', x='job_skills', y='skill_count', ax=ax[i], title=job_title)
    ax[i].invert_yaxis()
    ax[i].set_ylabel('')
    ax[i].get_legend().remove()
    ax[i].set_xlim(0, 120000) # make the scales the same

fig.suptitle('Counts of Top Skills in Job Postings', fontsize=15)
fig.tight_layout() # fix the overlap
plt.show()

# %%
for i, job_title in enumerate(job_titles):
    df_skills_count[df_skills_count['job_title_short'] == job_title].head(5).plot(kind='barh', x='job_skills', y='skill_count', title=job_title)
    plt.gca().invert_yaxis()
    plt.gca().set_ylabel('')
    plt.gca().get_legend().remove()
    plt.show()

# %%
# savefig(): Save the current figure.
# Save the figure in the file path of your choice
plt.savefig('top_skills.png')

plt.show()

# %%
# Pie charts
#  Count True and False values
work_from_home = df['job_work_from_home'].value_counts()

# %%
# Plotting the pie chart
plt.figure(figsize=(6,6))
plt.pie(work_from_home, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Work from Home Status')
plt.show()

# %%
# Count True and False values
job_no_degree = df['job_no_degree_mention'].value_counts()

# %%
job_health_insurance = df['job_health_insurance'].value_counts()

# %%
# Set up the matplotlib figure
fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

# Data Analyst Salaries
plt.subplot(1, 3, 1)
plt.pie(work_from_home, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Work from Hom Offered')

# Job No Degree
plt.subplot(1, 3, 2)
plt.pie(job_no_degree, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Degree Requirement')

# Job Health Insurance
plt.subplot(1, 3, 3)
plt.pie(job_health_insurance, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Health Insurance Offered')

plt.tight_layout()
plt.show()

# %%
# rewrite the above with a for loop
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

# plt.suptitle('Benefit Analysis of Data Jobs', fontsize=16)
plt.show()

# %%
# Scatter Plots
df = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
# Explode the 'job_skills' into individual rows
df_exploded = df.explode('job_skills')

skill_stats = df_exploded.groupby('job_skills').agg(
    median_salary=('salary_year_avg', 'median'),
    skill_count=('job_skills', 'count')
)

# Limit to the top 10 skills by highest salary
skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(10)

skill_stats
# Out:
#             median_salary  skill_count
# job_skills
# sql               92500.0        92428
# excel             84479.0        66860
# python            98500.0        57190
# tableau           95000.0        46455
# power bi          90000.0        39380
# r                 92527.5        29996
# sas               90000.0        27998
# powerpoint        85000.0        13822
# word              80000.0        13562
# sap               90000.0        11280

# %%
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title('Salary vs. Count of Job Postings for Top 10 Skills')
plt.tight_layout()
plt.show()

# %%
# Text
# text: Add text annotations to the plot.
# Common Arguments
# x: The x-coordinate for the text
# y: The y-coordinate for the text
# s: The text to display
# fontsize: The font size of the text
# color: The color of the text
# ha: Horizontal alignment of the text
# va: Vertical alignment of the text

# %%
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')

# plt.text() function to label the points
for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)

plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title('Salary vs. Count of Top Skills in Data Analyst Jobs')
plt.tight_layout()
plt.show()

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()
# create a new column for month number
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# Explode the job_skills column and pivot
df_DA_explode= df_DA.explode('job_skills')
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills',  aggfunc='size', fill_value=0)

# sort the skills by count
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_pivot = df_DA_pivot.drop('Total')

# Use month names for plotting
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_pivot = df_DA_pivot.set_index('job_posted_month')
df_DA_pivot = df_DA_pivot.drop(columns='job_posted_month_no')

# Get the top 5 skills
df_DA_pivot.iloc[:, :5].plot(kind='line')

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
""" Basic Customizations
Line Styles and Colors
Line Style
linestyle: Change the line style
Line Color
color: Change the line color
colormap: Change the color sheme for all data points
Line Width
linewidth: Change the line width
Markers
Marker Style
marker: Change the marker style
Marker Size
markersize: Change the marker size"""

# %%
df_DA_pivot.iloc[:, :5].plot(
    kind='line',
    linewidth=4,
    linestyle=':', # options: '-', '--', '-.', ':'
    colormap='viridis', # options: 'viridis', 'plasma', 'inferno', 'magma', 'cividis'
    markersize=5,
    marker='o', # options: 'o', 'x', '+', '*', 's', ',', '.', '1', '2', '3', '4', ...
    figsize=(10, 5)
)

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
'''
Set Axis Limits
Set X Limit
xlim: Set the x-axis view limits
Set Y Limit
ylim: Set the y-axis view limits
Grid
Add Grid
grid: Add a grid to the plot
# Out:
#   File "<ipython-input-52-7626d9ca9086>", line 1
#     '''
#     ^
# SyntaxError: incomplete input

# %%
df_DA_pivot.iloc[:, :5].plot(
    kind='line',
    linewidth=4,
    linestyle='-', # options: '-', '--', '-.', ':'
    colormap='viridis', # options: 'viridis', 'plasma', 'inferno', 'magma', 'cividis'
    markersize=6,
    marker='o', # options: 'o', 'x', '+', '*', 's', ',', '.', '1', '2', '3', '4', ...
    # figsize=(10, 5)
)

plt.grid(True)

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylim(0, 12000)
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
'''
Histograms
hist(): plot a histogram.
Common Parameters:
x - the data you want to plot
bins - the number of bins or bin edges
range - lower and upper range of the bins
Syntax: hist(x, bins=None, range=None)'''
# Out:
# '\nhist(): plot a histogram.\nCommon Parameters:\nx - the data you want to plot\nbins - the number of bins or bin edges\nrange - lower and upper range of the bins\nSyntax: hist(x, bins=None, range=None)'

# %%
# Only get data analyst jobs in the US
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
# Plot histogram for yearly average salary


df_DA_US['salary_year_avg'].plot(kind='hist', bins=30, edgecolor='black')
# Alternatively, with matplotlib
# plt.hist(df_DA_US['salary_year_avg'], bins=30, edgecolor='black')

plt.title('Distribution of United States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary')
plt.ylabel('Number of Jobs')
plt.show()

# %%
df_DA_US['salary_year_avg'].plot(kind='hist', bins=40, edgecolor='black')
plt.xlim(0, 250000)

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))

plt.title('Distribution of United States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary')
plt.ylabel('Number of Jobs')
plt.show()

# %%
# Boxplot graphs
'''
boxplot(): plot a box plot
Common Parameters:
column - column(s) to plot
by - if specified, data will be grouped and a box plot for each group will be plotted
vert - if False, plots horizontal boxplots
Syntax: boxplot(column=['column1', 'column2', ...], by=None, vert=False)
General Info
Purpose:
Visualize the distribution of a dataset by displaying the summary statistics (minimum, first quartile, median, third quartile, and maximum).
Identify outliers and skewness in the data.
Compare distributions across multiple groups.'''
# Out:
# "\nboxplot(): plot a box plot\nCommon Parameters:\ncolumn - column(s) to plot\nby - if specified, data will be grouped and a box plot for each group will be plotted\nvert - if False, plots horizontal boxplots\nSyntax: boxplot(column=['column1', 'column2', ...], by=None, vert=False)\nGeneral Info\nPurpose:\nVisualize the distribution of a dataset by displaying the summary statistics (minimum, first quartile, median, third quartile, and maximum).\nIdentify outliers and skewness in the data.\nCompare distributions across multiple groups."

# %%
# Only get data analyst jobs
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the column for plotting
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
df_DA_US['salary_year_avg'].plot(kind='box', vert=False)
# Alternatively, you can use matplotlib
# plt.boxplot(df_DA_US['salary_year_avg'])

plt.title('Salary Distributions for Data Analyst in the US')
plt.ylabel('Median Salary ($USD)')
plt.show()

# %%
# plot histogram and boxplot for df_DA_US['salary_year_avg'] on same figure

fig, ax = plt.subplots(2, 1)
fig.tight_layout(h_pad=1)

df_DA_US['salary_year_avg'].plot(kind='hist', ax=ax[0], bins=30, edgecolor='black')
ax[0].set_title('Salary Distributions for Data Analyst in the US')
ax[0].set_xlabel('')
ax[0].set_ylabel('Frequency')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: '${0:g}k'.format(x/1000)))
# lines
ax[0].axvline(df_DA_US['salary_year_avg'].median(), color='r', linestyle='--')
ax[0].axvline(df_DA_US['salary_year_avg'].quantile(0.25), color='y', linestyle='--')
ax[0].axvline(df_DA_US['salary_year_avg'].quantile(0.75), color='y', linestyle='--')
ax[0].legend(['', 'Median', 'Q1 & Q3'])


df_DA_US['salary_year_avg'].plot(kind='box', ax=ax[1], vert=False)
ax[1].set_yticklabels('')
ax[1].set_xlabel('Median Salary ($USD)')
ax[1].set_ylabel('')
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: '${0:g}k'.format(x/1000)))
# lines
ax[1].axvline(df_DA_US['salary_year_avg'].median(), color='r', linestyle='--')
ax[1].axvline(df_DA_US['salary_year_avg'].quantile(0.25), color='y', linestyle='--')
ax[1].axvline(df_DA_US['salary_year_avg'].quantile(0.75), color='y', linestyle='--')
plt.show()

# %%
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

# filter for the job titles and country
df_US = df[(df['job_title_short'].isin(job_titles)) & (df['job_country'] == 'United States')].dropna(subset=['salary_year_avg'])

# %%
# list of salaries for each job title
job_list = [df_US[df_US['job_title_short'] == job_title]['salary_year_avg'] for job_title in job_titles]

plt.boxplot(job_list, labels=job_titles, vert=False)
plt.title('Salary Distribution in the United States')
plt.xlabel('Yearly Salary ($USD)')
plt.show()

# %%
plt.boxplot(job_list, labels=job_titles, vert=False)
plt.title('Salary Distributions in the United States')
plt.xlabel('Yearly Salary (USD)')
plt.xlim(0, 600000)

# Format x-axis to show 'Thousands'
ticks_x = plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K')
plt.gca().xaxis.set_major_formatter(ticks_x)
plt.show()

# %%
# list of salaries for each job title
job_list = [df_US[df_US['job_title_short'] == job_title]['salary_year_avg'] for job_title in job_titles]

plt.boxplot(job_list, labels=job_titles, vert=False)
plt.title('Salary Distribution in the United States')
plt.xlabel('Yearly Salary ($USD)')
plt.show()

# %%
# Only get data analyst jobs in the US
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
df_DA_US = df_DA_US.explode('job_skills')

df_DA_US[['salary_year_avg', 'job_skills']].head(5)
# Out:
#      salary_year_avg job_skills
# 109          89000.0     python
# 109          89000.0          r
# 109          89000.0    alteryx
# 109          89000.0    tableau
# 180          90250.0      excel

# %%
df_DA_top_pay = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='median', ascending=False)

df_DA_top_pay = df_DA_top_pay.head(10)

df_DA_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
df_DA_skills = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.head(10).sort_values(by='median', ascending=False)

df_DA_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig, ax = plt.subplots(2, 1)

# Top 10 Highest Paid Skills for Data Analysts
df_DA_top_pay[::-1].plot(kind='barh', y='median', ax=ax[0], legend=False)
ax[0].set_title('Top 10 Highest Paid Skills for Data Analysts')
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))


# Top 10 Most In-Demand Skills for Data Analysts
df_DA_skills[::-1].plot(kind='barh', y='median', ax=ax[1], legend=False)
ax[1].set_title('Top 10 Most In-Demand Skills for Data Analysts')
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary (USD)')
ax[1].set_xlim(ax[0].get_xlim())  # Set the same x-axis limits as the first plot
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
# Only get data analyst jobs in the US
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
df_DA_US['salary_year_avg'].plot(kind='hist', bins=30, edgecolor='black')

plt.title('Distribution of United States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary (USD)')
plt.ylabel('Number of Jobs')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
plt.show()

# %%
sns.displot(df_DA_US['salary_year_avg'], kind='kde', fill=True, common_norm=False)

# this is all the same
plt.title('Distribution of United States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary (USD)')
plt.ylabel('Density') # Density is the probability of a random variable taking on a particular value
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
plt.show()

# %%
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

# filter for the job titles and country
df_US = df[(df['job_title_short'].isin(job_titles)) & (df['job_country'] == 'United States')].dropna(subset=['salary_year_avg'])

# list of salaries for each job title
job_list = [df_US[df_US['job_title_short'] == job_title]['salary_year_avg'] for job_title in job_titles]

# %%
sns.boxplot(data=df_US, x='salary_year_avg', y='job_title_short')
sns.set_theme(style='ticks')

# this is all the same
plt.title('Salary Distributions in the United States')
plt.xlabel('Yearly Salary (USD)')
plt.ylabel('')
plt.xlim(0, 600000)
ticks_x = plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K')
plt.gca().xaxis.set_major_formatter(ticks_x)
plt.show()

# %%
fig, ax = plt.subplots(2, 1)

sns.set_theme(style='ticks')

# Top 10 Highest Paid Skills for Data Analysts
sns.barplot(data=df_DA_top_pay, x='median', y=df_DA_top_pay.index, hue='median', ax=ax[0], palette='dark:b_r')
ax[0].legend().remove()
# original code:
# df_DA_top_pay[::-1].plot(kind='barh', y='median', ax=ax[0], legend=False)
ax[0].set_title('Top 10 Highest Paid Skills for Data Analysts')
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))


# Top 10 Most In-Demand Skills for Data Analystsr')
sns.barplot(data=df_DA_skills, x='median', y=df_DA_skills.index, hue='median', ax=ax[1], palette='light:b')
ax[1].legend().remove()
# original code:
# df_DA_skills[::-1].plot(kind='barh', y='median', ax=ax[1], legend=False)
ax[1].set_title('Top 10 Most In-Demand Skills for Data Analysts')
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary (USD)')
ax[1].set_xlim(ax[0].get_xlim())  # Set the same x-axis limits as the first plot
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

plt.tight_layout()
plt.show()
